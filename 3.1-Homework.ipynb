# %% [markdown]
# # 3.1 Homework
# ----
# ### 1. **What is an <font color= red>algorithm</font>?**
#
# * #### _An algorithm is a series of steps to solve a problem at hand_
#
#
# ### 2. **Why is <font color=red>Python</font> considered to be a high-level language?**
#
# * #### _Python is considered a high level language because:_
#     * _It takes less time to write_
#     * _It shorter and easier to read_
#     * _It is more likely to be correct/ error free when we run them_
#
#
# ### 3. **Is Python a <font color=red>Natural</font> or a <font color=red>Formal language</font>?**
#
# * #### Python would be considered a _formal language_
#
#
# ### 4. **<font color=red>Variable</font> names may not start with certain characters - name two.**
#
# * ### _Numbers and symbols_
#
#
# ### 5. **What is a <font color=red>Semantic error</font>?**
#
# * #### _Code that is grammatically correct but doesn't make any sense. It does not produce the expected reults_.
#
#
# ### 6. **What is the <font color=red>#1</font> rule of coding / debugging?**
#
# * #### _The #1 rule is complexity is the enemy of efficiency!_
#
#
# ### 7. **list <font color=red>5</font> Python reserved words.**
#
# * #### _False_
# * #### _True_
# * #### _Except_
# * #### _Not_
# * #### _Yield_
#
#
# ### 8. **<font color=red>Add a name, and web link</font> for any Python coding article, in your markdown cell**
#
# #### [What is the Python programming language?](https://acloudguru.com/blog/engineering/what-is-the-python-programming-language%EF%BF%BC)

# %%
#This is a multi line comment
"""
My name is Jonathan Salgado 
My favorite food is Enchiladas
My dream job is to become an entrepreneur
"""

#Assign 5 different data types to 5 different variables. At least one datatype must be a string.

J= str('Hello Savvycoders')
print(J)


S= int(22)
print(S)


M= float(26.2)
print(M)


G= range (250)
print(G)

x= list ['purple', 'red', 'black']
print(x)


#Print the length of your string.

print('The length of j is ...',len(J))


#Print the the index value of the 4th character in your string

print("Element 4 = ", J[4])


#create a new variable called savvy, and assign it the string with this phrase "Learning Data Analytics and Python is Awesome!"


Savvy  = "Learning Data Analytics and Python is Awesome!"

print(Savvy)


#return a range of characters that slices the above string from the beginning of "ing" up to before "and"


print(Savvy[5:23])


#Replace "Awesome" with "great" in the string


print(Savvy.replace("Awesome", "Great"))


#Create and assign 3 more variables called name, age and length using the multi-variable naming method


name, age, length = "Jonathan", "23", "5 ft 6"

print(name, age, length) 


#Format a new string called 'miniBio' using variables in curly brackets to complete this phrase... "Hi my name is (name), I am (tall) and (so) old today."

minibio= "Hi my name is {}, I am {} tall and {} years old today."

print(minibio.format(name, length, age))


#cast and print the age variable to a float


age = float(23)

print(age)
# Out:
# Hello Savvycoders
# 22
# 26.2
# range(0, 250)
# list['purple', 'red', 'black']
# The length of j is ... 17
# Element 4 =  o
# Learning Data Analytics and Python is Awesome!
# ing Data Analytics
# Learning Data Analytics and Python is Great!
# Jonathan 23 5 ft 6
# Hi my name is Jonathan, I am 5 ft 6 tall and 23 years old today.
# 23.0
